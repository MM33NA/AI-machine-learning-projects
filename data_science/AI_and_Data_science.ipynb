# %% [markdown]
# <a href="https://colab.research.google.com/github/MM33NA/AI-machine-learning-projects/blob/main/data_science/AI_and_Data_science.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Applied Data Science with Python**
# - Libraries + code
#   - Nympy, Pandas, Matplotlib, Seaborn
#
# - Math & Stats
#   - Theory Probability, Probabiliy Distribution, Hypothesis testing
#
#   - Scaling + transformation

# %% [markdown]
# **Lifecycle of a Data Science | ML *Project***
#
# **Example:** Coca-cola company wants to predict the sales of cold drink for the product coke-zero for upcoming 6 months.
#
# Things we need:
# - Historic Data / Data collection
#
# | Data | Temp | Price | Discount | Comp Sales| Number of channels | sales |
# | 1   |
#
# Suppose the data is for 3 years.
#
# Steps:
#  - Simple data check (data type, missing values, errors, outliers,
#  - Data cleaning
#  - Exploratory Data analysis (understanding the data in and out)
#    - Average, seasonality pattern, good/bad months, difference in sales, which discount is giving highest sale, etc.)
#    - EDA can be conducted using Graphs, and Maths & Stats
#    - Graphs includes, drends lines, scattered plots etc.
#    - Maths & Stats includes importance of variables, distribution of data, relationship test
#    - Graphs gives approximate idea
#    - Maths & Stats gives --> Confident analysis
#
# - Modeling [Data prep for modeling -> Training & Testing of Algorithms]
#   - It covers Machine learning part
